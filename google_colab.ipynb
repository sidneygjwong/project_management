# %% [markdown]
# # Getting Started in Google Colab

# %% [markdown]
# Google Colab is a hosted Jupyter Notebook that allows you to combine executable code and text in a single document. If you're familiar with RMarkdown, then you're no stranger to sharing your code, results, and commentary in a reproducible format.
#
# Let's start by running a simple bit of code!

# %%
j = 1 + 1
j
# Out:
# 2

# %% [markdown]
# As part of your standard Google account, you're provided a limited number of computational capabilities and RAM, called computes. This should be plenty for most projects. Let's try another example!

# %%
k = "Hello World!"
print(k)
# Out:
# Hello World!

# %% [markdown]
# Cognratulations! You're well on your way to be a coding genius!

# %% [markdown]
# ## Using R in Google Colab

# %% [markdown]
# If you're unfamiliar with Python, that's okay! You also run Google Colab with R or Julia by changing the Runtime. If you want to run R code without changing the Runtime, you can run R by activating R magic by running the following code:

# %% [markdown]
# ```
# %load_ext rpy2.ipython
# ```

# %% [markdown]
# Try running the code below:

# %%
# activate R magic
# %load_ext rpy2.ipython

# %% [markdown]
# Now you can run R in your Google Colab by prefixing your code chunk with ```%%R```.

# %%
# %%R
# n <- 1 + 1
# n
# Out:
# [1] 2

# %% [markdown]
# Cool! You'll notice the Red squiggly line to indicate an error in your code, but it's only because it's trying to interpret your code in Python. Let's try another example:

# %%
# %%R
# m <- "Hello"
# print(m)
# Out:
# [1] "Hello"

# %% [markdown]
# ## Integrating with Google Drive

# %% [markdown]
# One benefit of Google Colab is that you can integrate it with your Google Drive. You will first need to mount your personal Google Drive account using the following code.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# ```

# %% [markdown]
# Here's a live example:

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Once you have successfully mounted your personal Google Drive in Colab, you should see the following output:

# %% [markdown]
# ```
# Mounted at /content/drive
# ```

# %% [markdown]
# You can then need to set the working directory with the following code followed by the folder location of whatever project you're working on.
#
# ```
# %cd /content/drive/MyDrive/
# ```

# %% [markdown]
# You may receive a security alert from Google, but that's okay!

# %%
# Set Working Directory
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %% [markdown]
# ## Summary

# %% [markdown]
# This is just a quick introduction to Google Colab, and Jupyter Notebooks, but once you've mastered these basics you should be able to run all sorts of projects in this environment and share them with your collaborators.
#
# If you have any questions, please feel free to reach out to me: sidney.wong@pg.canterbury.ac.nz
